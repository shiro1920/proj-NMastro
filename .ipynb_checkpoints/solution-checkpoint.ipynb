# %%
import numpy as  np
import time
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
x0 = 0
x1 = 1
t0 = 0
t1 = 1
n = 100
m = 10
c = 1

# %%
### 这里设置的空间步长与时间步长均为0.001
X = np.linspace(x0, x1, m+1)
T = np.linspace(t0, t1, n+1)
[x, t] = np.meshgrid(X,T)
dx = (x1 - x0)/m
dt = (t1 - t0)/n

# %%
dt, dx/c
# Out:
# (0.01, 0.1)

# %%
U = np.zeros(np.shape(x))
#U_init = np.sin(2*np.pi*X)  #初始条件 U(x,0) = f(x)
U_init = np.zeros(T.shape)
U_init[0:2] = 1
#U_left = -np.sin(2*np.pi*c*T) #左边界 U(0,t) = f(t) 对于有限边界，左边界必须给定边界值，右边界不能给定边界值
#U_right= np.sin(2*np.pi*(X[-1]-c*T))# 右边界 U(x=1,t) 给定右边界属于过给定问题，但是在空间差分格式中保证给到合适的边界值
U_left  = np.zeros(X.shape)
U_right = np.ones(X.shape)
#U_init[20:40] = 1

#U_ana = np.sin(2*np.pi*(x-c*t)) # 对流方程其解为 u(x,t) = f(x-ct)

# %%
x.shape
# Out:
# (101, 11)

# %%
#up-wind
U1 = np.zeros(x.shape)
U1[:,0] = U_init #t=0 u(x,t=0) = f(x)
U1[0,:] = U_left #x=0 u(x=0,t) = f(t)
for n in range(len(T)-1):
    U1[1:-1, n+1] = U1[1:-1, n] - c*dt/dx*(U1[1:-1, n] - U1[0:-2,n]) #u(i,n+1) = u(i,n) - c*(dt/dx)(u(i,n)-u(i-1,n)), (c>0)
    U1[-1, n+1] = U1[-1, n] - c*dt/dx*(U1[-1, n] - U1[-2,n]) #边界处

'''
#leapfrog 有问题，实际上直接知道了下一个时刻的解
U2 = np.zeros(np.shape(x))
U2[:,0] = U_init
U2[0,:] = U_left
U2[:,1] = U_ana[:,1] # 不应该直接使用解析解给定值
U2[-1,:] = U_ana[-1,:]
for n in range(len(T)-2):
    U2[1:-2, n+2] = U2[1:-2, n] - dt/dx*(U2[2:-1, n+1] - U2[0:-3,n+1])
    U2[-2, n+2] = U2[-2, n] - dt/dx*(U2[-1, n+1] - U2[-3,n+1])
'''

#time forward, space centering
U3 = np.zeros(np.shape(x))
U3[:,0] = U_init
U3[0,:] = U_left
U3[-1,:] = U_right  #这一步默认已知边界处所有时刻的值,即给定了右边界，过给定问题
for n in range(len(T)-1):
    # u(i,n+1)=u(i,n)-(0.5*c*dt/dx)*(u(i+1,n)-u(i-1,n))
    U3[1:-2, n+1] = U3[1:-2, n] - 0.5*c*dt/dx*(U3[2:-1, n] - U3[0:-3,n])     
    U3[-2, n+1] = U3[-2, n] - 0.5*c*dt/dx*(U3[-1, n] - U3[-3,n])
    
#Lax-Friedrichs
U4 = np.zeros(np.shape(x))
U4[:,0] = U_init
U4[0,:] = U_left
#U4[-1,:] = U_right
for n in range(len(T)-1):
    U4[1:-2, n+1] = 0.5*(U4[2:-1, n] + U4[0:-3,n]) - 0.5*c*dt/dx*(U4[2:-1, n] - U4[0:-3,n])
    U4[-2, n+1] = 0.5*(U4[-1, n] + U4[-3,n]) - 0.5*c*dt/dx*(U4[-1, n] - U4[-3,n])

#Lax-Wendroff
U5 = np.zeros(np.shape(x))
U5[:,0] = U_init
U5[0,:] = U_left
#U5[-1,:] = U_right
for n in range(len(T)-1):
    U5[1:-2, n+1] = U5[1:-2, n] - 0.5*dt/dx*(U5[2:-1, n] - U5[0:-3,n]) + 0.5*dt**2/dx**2*(U5[2:-1, n] -2*U5[1:-2, n] + U5[0:-3,n])
    U5[-2, n+1] = U5[-2, n] - 0.5*dt/dx*(U5[-1, n] - U5[-3,n]) + 0.5*dt**2/dx**2*(U5[-1, n] -2*U5[-2, n] + U5[-3,n])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #up-wind
# ----> 2 U1 = np.zeros((x,t))
#       3 U1[:,0] = U_init #t=0 u(x,t=0) = f(x)
#       4 U1[0,:] = U_left #x=0 u(x=0,t) = f(t)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
fig, ax = plt.subplots(1, 1,figsize=(10, 8))
mpl.rc('xtick',labelsize=5)
mpl.rc('ytick',labelsize=5)
plt.rcParams["xtick.top"] = False
plt.rcParams["ytick.right"] = False
plt.rcParams["xtick.minor.visible"] = False
plt.rcParams["ytick.minor.visible"] = False
mpl.rcParams['axes.linewidth'] =0.8
plt.rcParams["xtick.direction"] = "out"
plt.rcParams["ytick.direction"] = "out"
#fig.subplots_adjust(wspace=0.2, hspace=0.6)
im=ax.imshow(U5, origin='lower')
cb = plt.colorbar(im, fraction = 0.045, pad = 0.2)
font = {'size': 16}
cb.ax.tick_params(labelsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax.tick_params(which='major',length=1.7,width=0.5)
cb.set_label('colorbar',fontdict=font)
ax.tick_params(pad=0.2)
plt.show()

# %%
from matplotlib import animation
import matplotlib as mpl

fig = plt.figure(figsize = (6,4.5),dpi=100)
plt.grid(ls='--')
ani1, = plt.plot(X, U1[:,0],color='red', label="Up Wind")
#ani2, = plt.plot(X, U2[:,0],color='green', label="leapfrog")
ani3, = plt.plot(X, U3[:,0], color='m',label="time forward, space centering")
ani4, = plt.plot(X, U4[:,0], color='blue',label="Lax-Friedrichs")
ani5, = plt.plot(X, U5[:,0], color='darkorange',label="Lax-Wendroff")
                     
plt.xlabel("X", fontsize = 16)
plt.ylabel("Amptitude", fontsize = 16)
plt.legend(loc='best',fontsize=8)

text_ani = plt.text(0.1, 0, '',fontsize=12)
plt.ylim(-1.2,1.2)
def update(n):
    ani1.set_data(X, U1[:,n])
    #ani2.set_data(X, U2[:,n])
    ani3.set_data(X, U3[:,n])
    ani4.set_data(X, U4[:,n])
    ani5.set_data(X, U5[:,n])
    t = n/10.
    text_ani.set_text('t=%.3f'%t)
    return [ani1,ani3,ani4,ani5,text_ani]

ani = animation.FuncAnimation(fig=fig, func = update, frames = np.arange(0,11), interval = 2)
ani.save('ini_zero.gif')
plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14

fig = plt.figure(figsize = (6,4.5),dpi=100)
ax  = plt.subplot(111)
ax.set_xlabel("X", fontsize = 16)
ax.set_ylabel("Amptitude", fontsize = 16)

ti = 700
ax.plot(X, U1[:,ti], label="Up Wind")
#ax.plot(X, U2[:,ti], label="leapfrog")
#ax.plot(X, U3[:,ti], label="time forward, space centering")
ax.plot(X, U4[:,ti], label="Lax-Friedrichs")
ax.plot(X, U5[:,ti], label="Lax-Wendroff")

ax.legend(fontsize = 9)
#ax.set_ylim(-1,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 16
#      13 ax.set_ylabel("Amptitude", fontsize = 16)
#      15 ti = 700
# ---> 16 ax.plot(X, U1[:,ti], label="Up Wind")
#      17 #ax.plot(X, U2[:,ti], label="leapfrog")
#      18 #ax.plot(X, U3[:,ti], label="time forward, space centering")
#      19 ax.plot(X, U4[:,ti], label="Lax-Friedrichs")
#
# IndexError: index 700 is out of bounds for axis 1 with size 101

# %%
#Thomas追赶法解三对角矩阵方程Ax=b
def Thomas(La, Mb, Uc, b):
    """
    Arguments:
        La -- [lower item for tri-diagonal matrix]
        Mb -- [mian item for tri-diagonal matrix]
        Uc -- [upper item for tri-diagonal matrix]
        b -- [AX = b, where A is the tri-diagonal matrix]
    """
    n = len(Mb)
    Uc[0] = Uc[0] / Mb[0]
    for i in range(1, n-1):
        Uc[i] = Uc[i] / (Mb[i] - La[i - 1] * Uc[i - 1])
    b[0] = b[0] / Mb[0]
    for i in range(1, n):
        b[i] = (b[i] - La[i-1]*b[i-1]) / (Mb[i] - La[i-1] * Uc[i-1])
    ls = list(range(n-1))[::-1]
#     print(b)
    for i in ls:
        b[i] = b[i] - Uc[i]*b[i+1]
    return b

# %%
#full implicit（全隐）
U6 = np.zeros(np.shape(x))
U6[:,0] = U_ana[:,0]
U6[0,:] = U_ana[0,:]
U6[:,-1] = U_ana[:,-1]

for i in range(len(T)-1):
    a = -0.5*dt/dx*np.ones((len(U6[0,:])-3))#给出矩阵三条对角线的值
    b = np.ones((len(U6[0,:])-2))
    c = 0.5*dt/dx *np.ones((len(U6[0,:])-3))
    k = []
    for j in range(len(U6[0,:])-2):
        k.append(U6[i,j+1])
    
    k[0] += 0.5*dt/dx*U6[i+1,0]
    k[-1] -= 0.5*dt/dx*U6[i+1,-1]#计算Ax=b中的b
    
    U6[i+1,1:-1] = Thomas(a,b,c,k)#求x



#Crack-Nicholson
U7 = np.zeros(np.shape(x))
U7[:,0] = U_ana[:,0]
U7[0,:] = U_ana[0,:]
U7[:,-1] = U_ana[:,-1]

for i in range(len(T)-1):
    a = -0.25*dt/dx*np.ones((len(U7[0,:])-3))
    b = np.ones((len(U7[0,:])-2))
    c = 0.25*dt/dx *np.ones((len(U7[0,:])-3))
    k = []
    for j in range(len(U7[0,:])-2):
        k.append(U7[i,j+1]-0.25*dt/dx*(U7[i,j+2]- U7[i,j]))
    
    k[0] += 0.25*dt/dx*U7[i+1,0]
    k[-1] -= 0.25*dt/dx*U7[i+1,-1]
    U7[i+1,1:-1] = Thomas(a,b,c,k)

    

#跳点（本质是显格式）
U8 = np.zeros(np.shape(x))
U8[:,0] = U_ana[:,0]
U8[0,:] = U_ana[0,:]
U8[:,-1] = U_ana[:,-1]

for i in range(len(T)-1):
    for j in range(len(X)-2):
        if (i+j+1)%2 == 0:
            U8[i+1,j+1] = U8[i,j+1] - 0.5*dt/dx*(U8[i,j+2]-U8[i,j])
    for j in range(len(X)-2):
        if (i+j+1)%2 != 0:
            U8[i+1,j+1] = U8[i,j+1] - 0.5*dt/dx*(U8[i+1,j+2]-U8[i+1,j])
